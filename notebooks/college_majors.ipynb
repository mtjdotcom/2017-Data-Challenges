# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
% matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads_2.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Major_category                    Engineering
# Total                                    2339
# Sample_size                                36
# Men                                      2057
# Women                                     282
# ShareWomen                           0.120564
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total  Sample_size            Men  \
# count  173.000000   173.000000     173.000000   173.000000     173.000000
# mean    87.000000  3879.815029   39167.716763   356.080925   16637.358382
# std     50.084928  1687.753140   63354.613919   618.361022   28063.394844
# min      1.000000  1100.000000     124.000000     2.000000     119.000000
# 25%     44.000000  2403.000000    4361.000000    39.000000    2110.000000
# 50%     87.000000  3608.000000   15058.000000   130.000000    5347.000000
# 75%    130.000000  5503.000000   38844.000000   338.000000   14440.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# count     173.000000  173.000000     173.000000     173.000000     173.000000
# mean    22530.358382    0.522550   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]

# %%
raw_data_count
# Out:
# 173

# %%
recent_grads =  recent_grads.dropna()

# %%
recent_grads.shape[0] - raw_data_count
# Out:
# -1

# %%
recent_grads.plot(x='Sample_size', y="Median", kind="scatter", title="Sample Size and Median")

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="Scatter")

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter")

# %%
recent_grads["Sample_size"].plot(kind="hist")

# %%
recent_grads["Sample_size"].hist(bins=50)

# %%
recent_grads["Median"].hist(bins=25)

# %%
recent_grads["Employed"].hist(bins=25)

# %%
recent_grads["Full_time"].hist(bins=25)

# %%
recent_grads["Men"].hist(bins=25)

# %%
recent_grads["ShareWomen"].hist(bins=100)

# %%
recent_grads["ShareWomen"].plot(kind="hist")

# %%
recent_grads["Unemployment_rate"].hist(bins=25)

# %%
recent_grads["Women"].hist(bins=25)

# %%
scatter_matrix(recent_grads[['Women', 'Men']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118e9d750>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119b9f1d0>]], dtype=object)

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(1,5):
    ax = fig.add_subplot(4,1,r)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119ce6450>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b2e5490>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bd163d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c65cc10>]], dtype=object)

# %%
recent_grads[0:5].plot.bar(x="Major", y="Women")

# %% [markdown]
# Use bar plots to compare the percentages of women (ShareWomen) from the 10 highest paying majors and from the 10 lowest paying majors.
#
# Use bar plots to compare the unemployment rate (Unemployment_rate) from the 10 highest paying majors and from the 10 lowest paying majors.

# %%
major_small = recent_grads.nsmallest(10,"Median")

# %%
major_small
# Out:
#      Rank  Major_code                                          Major  \
# 172   173        3501                                LIBRARY SCIENCE
# 171   172        5203                          COUNSELING PSYCHOLOGY
# 169   170        5201                         EDUCATIONAL PSYCHOLOGY
# 170   171        5202                            CLINICAL PSYCHOLOGY
# 168   169        3609                                        ZOOLOGY
# 166   167        6001                         DRAMA AND THEATER ARTS
# 167   168        3302                       COMPOSITION AND RHETORIC
# 165   166        2603                        OTHER FOREIGN LANGUAGES
# 162   163        5502                    ANTHROPOLOGY AND ARCHEOLOGY
# 163   164        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
#
#                 Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# 172                  Education   1098            2    134    964    0.877960
# ...

# %%
major_pivot = pd.pivot_table(recent_grads, index="Major", values=["Median", "ShareWomen"])

# %%
major_small = major_pivot.nsmallest(10,"Median")

# %%
major_small
# Out:
#                                                Median  ShareWomen
# Major
# LIBRARY SCIENCE                                 22000    0.877960
# COUNSELING PSYCHOLOGY                           23400    0.798746
# CLINICAL PSYCHOLOGY                             25000    0.799859
# EDUCATIONAL PSYCHOLOGY                          25000    0.817099
# ZOOLOGY                                         26000    0.637293
# COMPOSITION AND RHETORIC                        27000    0.666119
# DRAMA AND THEATER ARTS                          27000    0.629505
# OTHER FOREIGN LANGUAGES                         27500    0.690111
# ANTHROPOLOGY AND ARCHEOLOGY                     28000    0.968954
# COMMUNICATION DISORDERS SCIENCES AND SERVICES   28000    0.707136

# %%
major_large = major_pivot.nlargest(10,"Median")

# %%
major_large
# Out:
#                                            Median  ShareWomen
# Major
# PETROLEUM ENGINEERING                      110000    0.120564
# MINING AND MINERAL ENGINEERING              75000    0.101852
# METALLURGICAL ENGINEERING                   73000    0.153037
# NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000    0.107313
# CHEMICAL ENGINEERING                        65000    0.341631
# NUCLEAR ENGINEERING                         65000    0.144967
# ACTUARIAL SCIENCE                           62000    0.535714
# ASTRONOMY AND ASTROPHYSICS                  62000    0.441356
# AEROSPACE ENGINEERING                       60000    0.196450
# BIOMEDICAL ENGINEERING                      60000    0.119559

# %%
major_large.plot.bar(x="Median", y="ShareWomen")

# %%
major_small.plot.bar(x="Median", y="ShareWomen")

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads[:10].plot.bar(x="Major", y="ShareWomen", legend=False)

# %%
recent_grads[163:].plot.bar(x="Major", y="ShareWomen", legend=False)

# %%
recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", legend=False)

# %%
recent_grads[163:].plot.bar(x="Major", y="Unemployment_rate", legend=False)
