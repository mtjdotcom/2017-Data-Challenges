# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

# %%
airlines = pd.read_csv("airlines.csv")
airports = pd.read_csv("airports.csv")
routes = pd.read_csv("routes.csv")

# %%
m = Basemap(projection="merc", llcrnrlat=-80, urcrnrlat=80, llcrnrlon=-180, urcrnrlon=180)

# %%
longitudes = airports["longitude"].tolist()
latitudes = airports["latitude"].tolist()
x, y = m(longitudes, latitudes)

# %%
fig = plt.figure(figsize=(15,20))
m.scatter(x, y, s=1)
m.drawcoastlines()
plt.title("Scaled up Earth")
plt.show()

# %%
airports.columns
# Out:
# Index([u'name', u'city', u'country', u'code', u'icao', u'latitude',
#        u'longitude', u'altitude', u'offset', u'dst', u'timezone'],
#       dtype='object')

# %%
airports.head()
# Out:
#                                           name          city  \
# 0                               Goroka Airport        Goroka
# 1                               Madang Airport        Madang
# 2                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3                               Nadzab Airport        Nadzab
# 4  Port Moresby Jacksons International Airport  Port Moresby
#
#             country code  icao  latitude   longitude  altitude offset dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282     10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20     10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388     10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239     10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146     10   U
#
#                timezone
# 0  Pacific/Port_Moresby
# 1  Pacific/Port_Moresby
# 2  Pacific/Port_Moresby
# 3  Pacific/Port_Moresby
# 4  Pacific/Port_Moresby

# %%
for index, row in airports.iterrows():
    if row["country"] == "United States":
        print(index, row["city"])
# Out:
# (3200, 'Barter Island')
# (3201, 'Cape Lisburne')
# (3202, 'Point Lay')
# (3203, 'Hilo')
# (3204, 'Orlando')
# (3205, 'Bettles')
# (3206, 'Clear Mews')
# (3207, 'Indian Mountains')
# (3208, 'Fort Yukon')
# (3209, 'Sparrevohn')
# (3210, 'Fort Richardson')
# (3211, 'Tatalina')
# (3212, 'Cape Romanzof')
# (3213, 'Bedford')
# (3214, 'St. Paul Island')
# (3215, 'Cape Newenham')
# (3216, 'Point Barrow')
# (3217, 'Iliamna')
# (3218, 'Port Moller')
# (3219, 'Big Mountain')
# (3220, 'Oscoda')
# (3221, 'Fort Ord')
# (3222, 'Sacramento')
# (3223, 'Fort Irwin')
# (3224, 'Twenty Nine Palms')
# (3225, 'Fort Smith')
# (3226, 'Anchorage')
# (3227, 'Grants')
# (3228, 'Ponca City')
# (3229, 'Hunter Aaf')
# (3230, 'Grand Forks')
# (3231, 'Pine Bluff')
# (3232, 'Milton')
# (3233, 'Hana')
# (3234, 'Prescott')
# (3235, 'Trenton')
# (3236, 'Boston')
# (3237, 'Fairfield')
# (3238, 'Rome')
# (3239, 'Wendover')
# (3240, 'Mobile')
# (3241, 'Oakland')
# (3242, 'Omaha')
# (3243, 'Port Angeles')
# (3244, 'Kahului')
# (3245, 'Wichita')
# (3246, 'Kansas City')
# (3247, 'Madison')
# (3248, 'Dillingham')
# (3249, 'Harrison')
# (3250, 'Phoenix')
# (3251, 'Bangor')
# (3252, 'Fort Lauderdale')
# (3253, 'Longview')
# (3254, 'Andersen')
# (3255, 'Spokane')
# (3256, 'Hollywood')
# (3257, 'San Francisco')
# (3258, 'Cutbank')
# (3259, 'Louisiana')
# (3260, 'Gainesville')
# (3261, 'Memphis')
# (3262, 'Douglas')
# (3263, 'Delta Junction')
# (3264, 'Waco')
# (3265, 'Annette Island')
# (3266, 'Caribou')
# (3267, 'Jacksonville')
# (3268, 'Redstone')
# (3269, 'Fort Bragg')
# (3270, 'Dalhart')
# (3271, 'Del Rio')
# (3272, 'Los Angeles')
# (3273, 'Anniston')
# (3274, 'Cleveland')
# (3275, 'Dover')
# (3276, 'Cincinnati')
# (3277, 'Fort Meade')
# (3278, 'China Lake')
# (3279, 'Huron')
# (3280, 'Juneau')
# (3281, 'Lafayette')
# (3282, 'Newark')
# (3283, 'Boise')
# (3284, 'Indian Springs')
# (3285, 'Garden City')
# (3286, 'Minot')
# (3287, 'Wahiawa')
# (3288, 'Montgomery')
# (3289, 'Robinson')
# (3290, 'Dallas')
# (3291, 'Fort Carson')
# (3292, 'Helena')
# (3293, 'Miramar')
# (3294, 'Phoenix')
# (3295, 'Mary Esther')
# (3296, 'Hawthorne')
# (3297, 'Houlton')
# (3298, 'Enid')
# (3299, 'Point Mugu')
# (3300, 'Edwards Afb')
# (3301, 'Lake Charles')
# (3302, 'Kona')
# (3303, 'Myrtle Beach')
# (3304, 'Lemoore')
# (3305, 'Nantucket')
# (3306, 'Fort Eustis')
# (3307, 'Hopkinsville')
# (3308, 'Washington')
# (3309, 'Patuxent River')
# (3310, 'Palacios')
# (3311, 'Blytheville')
# (3312, 'Atlantic City')
# (3313, 'Oklahoma City')
# (3314, 'Pueblo')
# (3315, 'Presque Isle')
# (3316, 'Fort Lewis')
# (3317, 'Kodiak')
# (3318, 'Opolu')
# (3319, 'Fort Lauderdale')
# (3320, 'Muskogee')
# (3321, 'International Falls')
# (3322, 'Salt Lake City')
# (3323, 'Childress')
# (3324, 'Biloxi')
# (3325, 'Fort Benning')
# (3326, 'Fort Riley')
# (3327, 'Harrisburg')
# (3328, 'Lincoln')
# (3329, 'Lansing')
# (3330, 'Kamuela')
# (3331, 'Massena')
# (3332, 'Hickory')
# (3333, 'St. Petersburg')
# (3334, 'Fort Myers')
# (3335, 'Houston')
# (3336, 'Millinocket')
# (3337, 'Camp Springs')
# (3338, 'Winston-salem')
# (3339, 'Victorville')
# (3340, 'Crestview')
# (3341, 'Fort Drum')
# (3342, 'Port Huron')
# (3343, 'Bakersfield')
# (3344, 'El Paso')
# (3345, 'Harlingen')
# (3346, 'Columbia')
# (3347, 'Tucson')
# (3348, 'Pensacola')
# (3349, 'Pensacola')
# (3350, 'Red River')
# (3351, 'Houston')
# (3352, 'Buckley')
# (3353, 'Northway')
# (3354, 'Palmer')
# (3355, 'Pittsburgh')
# (3356, 'Barrow')
# (3357, 'Houston')
# (3358, 'Whidbey Island')
# (3359, 'Alice')
# (3360, 'Valdosta')
# (3361, 'Miami')
# (3362, 'Seattle')
# (3363, 'Chattanooga')
# (3364, 'Stratford')
# (3365, 'Jackson')
# (3366, 'Galveston')
# (3367, 'Long Beach')
# (3368, 'Dillingham')
# (3369, 'Williamsport')
# (3370, 'Indianapolis')
# (3371, 'Knobnoster')
# (3372, 'Akron')
# (3373, 'Greenwood')
# (3374, 'White Plains')
# (3375, 'West Hampton Beach')
# (3376, 'Jonesboro')
# (3377, 'Tonopah')
# (3378, 'West Palm Beach')
# (3379, 'San Diego')
# (3380, 'El Paso')
# (3381, 'Yuma')
# (3382, 'Carlsbad')
# (3383, 'Duluth')
# (3384, 'Bethel')
# (3385, 'Louisville')
# (3386, 'Fort Huachuca')
# (3387, 'Lihue')
# (3388, 'Terre Haute')
# (3389, 'Havre')
# (3390, 'Grant County Airport')
# (3391, 'Montpelier')
# (3392, 'San Nicolas Island')
# (3393, 'Richmond')
# (3394, 'Shreveport')
# (3395, 'Cordova')
# (3396, 'Norfolk')
# (3397, 'Beaumont')
# (3398, 'Savannah')
# (3399, 'Ogden')
# (3400, 'Nome')
# (3401, 'San Luis')
# (3402, 'St. Petersburg')
# (3403, 'Macon')
# (3404, 'Conroe')
# (3405, 'Deadhorse')
# (3406, 'San Antonio')
# (3407, 'Rochester')
# (3408, 'Coco Beach')
# (3409, 'Teterboro')
# (3410, 'Rapid City')
# (3411, 'Raleigh-durham')
# (3412, 'Dayton')
# (3413, 'Kenai')
# (3414, 'Mcalester')
# (3415, 'Niagara Falls')
# (3416, 'Bryan')
# (3417, 'Wright')
# (3418, 'Newport News')
# (3419, 'Alexandria')
# (3420, 'Altus')
# (3421, 'Tucson')
# (3422, 'Minot')
# (3423, 'Marysville')
# (3424, 'Kankakee')
# (3425, 'Goldsboro')
# (3426, 'Providence')
# (3427, 'Salisbury')
# (3428, 'Rancho Murieta')
# (3429, 'Burbank')
# (3430, 'Detroit')
# (3431, 'Tampa')
# (3432, 'Pembina')
# (3433, 'Fort Polk')
# (3434, 'Fairbanks')
# (3435, 'Hibbing')
# (3436, 'Lufkin')
# (3437, 'Midland')
# (3438, 'Green Bay')
# (3439, 'Ardmore')
# (3440, 'Wrightstown')
# (3441, 'Cherry Point')
# (3442, 'Santa Barbara')
# (3443, 'Bush Field')
# (3444, 'Williston')
# (3445, 'Little Rock')
# (3446, 'Newburgh')
# (3447, 'Baudette')
# (3448, 'Sacramento')
# (3449, 'Homer')
# (3450, 'Fort Leonardwood')
# (3451, 'Marietta')
# (3452, 'Spokane')
# (3453, 'Houghton Lake')
# (3454, 'Panama City')
# (3455, 'Dallas-Fort Worth')
# (3456, 'Melbourne')
# (3457, 'Tacoma')
# (3458, 'Austin')
# (3459, 'Columbus')
# (3460, 'Gwinn')
# (3461, 'Knoxville')
# (3462, 'Fort Hood')
# (3463, 'St. Louis')
# (3464, 'Millville')
# (3465, 'Wichita Falls')
# (3466, 'Cincinnati')
# (3467, 'Atlanta')
# (3468, 'Merced')
# (3469, 'Sacramento')
# (3470, 'Grand Rapids')
# (3471, 'Wink')
# (3472, 'Fresno')
# (3473, 'Vero Beach')
# (3474, 'Imperial')
# (3475, 'Nashville')
# (3476, 'Laredo')
# (3477, 'Anchorage')
# (3478, 'Kotzebue')
# (3479, 'Altoona')
# (3480, 'Abilene')
# (3481, 'El Dorado')
# (3482, 'New York')
# (3483, 'Tallahassee')
# (3484, 'West Chicago')
# (3485, 'Waco')
# (3486, 'Augusta')
# (3487, 'Hillsboro')
# (3488, 'Jackson')
# (3489, 'Molokai')
# (3490, 'Fort Knox')
# (3491, 'Jacksonville')
# (3492, 'San Angelo')
# (3493, 'Calexico')
# (3494, 'Chico')
# (3495, 'Burlington')
# (3496, 'Jacksonville')
# (3497, 'Durango')
# (3498, 'Washington')
# (3499, 'College Station')
# (3500, 'Spokane')
# (3501, 'Milwaukee')
# (3502, 'Abilene')
# (3503, 'Columbia')
# (3504, 'Portland')
# (3505, 'Miami')
# (3506, 'West Palm Beach')
# (3507, 'Fort Worth')
# (3508, 'Ogdensburg')
# (3509, 'Seattle')
# (3510, 'San Antonio')
# (3511, 'Honolulu')
# (3512, 'Des Moines')
# (3513, 'New Bern')
# (3514, 'San Diego')
# (3515, 'Monroe')
# (3516, 'Sumter')
# (3517, 'Ontario')
# (3518, 'Greenvile')
# (3519, 'Roswell')
# (3520, 'Detroit')
# (3521, 'Brownsville')
# (3522, 'Dothan')
# (3523, 'Wildwood')
# (3524, 'Mount Clemens')
# (3525, 'Farmington')
# (3526, 'Corpus Christi')
# (3527, 'Syracuse')
# (3528, 'Key West')
# (3529, 'Chicago')
# (3530, 'San Jose')
# (3531, 'Hobbs')
# (3532, 'Philadelphia')
# (3533, 'Denver')
# (3534, 'Philadelphia')
# (3535, 'Sioux City')
# (3536, 'Macon')
# (3537, 'Truth Or Consequences')
# (3538, 'Palmdale')
# (3539, 'San Antonio')
# (3540, 'El Centro')
# (3541, 'Columbus')
# (3542, 'Fayetteville')
# (3543, 'Fort Sill')
# (3544, 'Princeton')
# (3545, 'Dayton')
# (3546, 'Galena')
# (3547, 'Chandler')
# (3548, 'Mineral Wells')
# (3549, 'Wichita')
# (3550, 'New Orleans')
# (3551, 'Beaufort')
# (3552, 'Texarkana')
# (3553, 'Plattsburgh')
# (3554, 'Aberdeen')
# (3555, 'Tucumcari')
# (3556, 'Anchorage')
# (3557, 'Killeen')
# (3558, 'Zuni Pueblo')
# (3559, 'Bellingham')
# (3560, 'Millington')
# (3561, 'Elkins')
# (3562, 'Hartford')
# (3563, 'Smithfield')
# (3564, 'Mobile')
# (3565, 'Mountain View')
# (3566, 'Santa Fe')
# (3567, 'Barking Sands')
# (3568, 'Deridder')
# (3569, 'Bradshaw Field')
# (3570, 'Nogales')
# (3571, 'Tampa')
# (3572, 'Belleville')
# (3573, 'Miami')
# (3574, 'Del Rio')
# (3575, 'Fort Myers')
# (3576, 'King Salmon')
# (3577, 'Muir')
# (3578, 'Lahania-kapalua')
# (3579, 'New York')
# (3580, 'Homestead')
# (3581, 'Riverside')
# (3582, 'Fort Leavenworth')
# (3583, 'Wallops Island')
# (3584, 'Alamogordo')
# (3585, 'Willow Grove')
# (3586, 'Cheyenne')
# (3587, 'Stockton')
# (3588, 'Charleston')
# (3589, 'Reno')
# (3590, 'Ketchikan')
# (3591, 'Detroit')
# (3592, 'Lompoc')
# (3593, 'Birmingham')
# (3594, 'Lakehurst')
# (3595, 'Las Vegas')
# (3596, 'Riverside')
# (3597, 'Modesto')
# (3598, 'Sacramento')
# (3599, 'Chicago')
# (3600, 'Colorado Springs')
# (3601, 'Buffalo')
# (3602, 'Sandusky')
# (3603, 'Everett')
# (3604, 'Mountain Home')
# (3605, 'Cedar City')
# (3606, 'Windsor Locks')
# (3607, 'Mcallen')
# (3608, 'Norfolk')
# (3609, 'Chicopee Falls')
# (3610, 'Lubbock')
# (3611, 'Chicago')
# (3612, 'Boca Raton')
# (3613, 'Fairbanks')
# (3614, 'Quantico')
# (3615, 'Clovis')
# (3616, 'Kaneohe Bay')
# (3617, 'Omaha')
# (3618, 'Gulkana')
# (3619, 'Watertown')
# (3620, 'Palm Springs')
# (3621, 'Amarillo')
# (3622, 'Fort Dodge')
# (3623, 'Shreveport')
# (3624, 'Topeka')
# (3625, 'Cotulla')
# (3626, 'Wilmington')
# (3627, 'Baton Rouge')
# (3628, 'Tyler')
# (3629, 'Baltimore')
# (3630, 'Hobart')
# (3631, 'Lanai')
# (3632, 'Alexandria')
# (3633, 'White Sands')
# (3634, 'Cold Bay')
# (3635, 'Tulsa')
# (3636, 'Sitka')
# (3637, 'Islip')
# (3638, 'Minneapolis')
# (3639, 'Wilmington')
# (3640, 'Unalaska')
# (3641, 'New Orleans')
# (3642, 'Portland')
# (3643, 'Oklahoma City')
# (3644, 'Albany')
# (3645, 'Valdez')
# (3646, 'Hampton')
# (3647, 'Santa Ana')
# (3648, 'Colombus')
# (3649, 'Kendall-tamiami')
# (3650, 'Oceana')
# (3651, 'Peru')
# (3652, 'Casper')
# (3653, 'Valparaiso')
# (3654, 'Selma')
# (3655, 'Key West')
# (3656, 'Charlotte')
# (3657, 'Las Vegas')
# (3658, 'Orlando')
# (3659, 'Florence')
# (3660, 'Great Falls')
# (3661, 'Youngstown')
# (3662, 'Fort Wainwright')
# (3663, 'Mackminnville')
# (3664, 'Macon')
# (3718, 'Pullman')
# (3719, 'Lewiston')
# (3720, 'Elmira')
# (3721, 'Ithaca')
# (3722, 'Monterey')
# (3723, 'Santa Barbara')
# (3724, 'Daytona Beach')
# (3769, 'Talkeetna')
# (3771, 'New Haven')
# (3772, 'Asheville')
# (3773, 'Greensboro')
# (3774, 'Sioux Falls')
# (3776, 'Manchester NH')
# (3777, 'Naples')
# (3779, 'Louisville')
# (3780, 'Charlottesville VA')
# (3781, 'Roanoke VA')
# (3782, 'Lexington KY')
# (3783, 'Evansville')
# (3784, 'Albuquerque')
# (3785, 'Bozeman')
# (3786, 'Billings')
# (3787, 'Butte')
# (3788, 'Traverse City')
# (3790, 'Bar Harbor')
# (3791, 'Rockland')
# (3792, 'Jacksn Hole')
# (3793, 'Rockford')
# (3798, 'Greenville')
# (3799, 'Bloomington')
# (3800, 'Gulfport')
# (3801, 'Kalamazoo')
# (3802, 'Toledo')
# (3803, 'Fort Wayne')
# (3804, 'Decatur')
# (3805, 'Cedar Rapids')
# (3806, 'La Crosse')
# (3807, 'Wassau')
# (3808, 'Peoria')
# (3809, 'Appleton')
# (3810, 'Rochester')
# (3811, 'Champaign')
# (3812, 'Manhattan')
# (3818, 'Franklin')
# (3823, 'Grand Junction')
# (3824, 'Saint George')
# (3825, 'Houston')
# (3826, "Port O\\\\'Connor")
# (3827, 'Sarasota')
# (3829, 'Van Nuys')
# (3830, 'Moline')
# (3831, 'Panama City')
# (3839, 'Bismarck')
# (3840, 'Telluride')
# (3843, 'Rapid City')
# (3844, 'Carlsbad')
# (3845, 'Flint')
# (3854, 'Redding')
# (3855, 'Eugene')
# (3856, 'Idaho Falls')
# (3857, 'Medford')
# (3859, 'Redmond-Bend')
# (3868, 'Akron')
# (3869, 'Huntsville')
# (3870, 'PARKERSBURG')
# (3871, 'MONTGOMERY')
# (3872, 'BRISTOL')
# (3873, 'PADUCAH')
# (3877, 'Page')
# (3879, 'Kalispell')
# (3880, 'Saginaw')
# (3881, 'Binghamton')
# (3887, 'Blythe')
# (3897, 'Petersburg')
# (3913, 'Sanford')
# (3914, 'Johnstown')
# (3955, 'Missoula')
# (3958, 'Grand Canyon')
# (3959, 'Sugar Land')
# (3961, 'Denver')
# (3962, 'Clovis')
# (3963, 'Fort Stockton')
# (3964, 'Las Vegas')
# (3965, 'Houston')
# (3966, 'La Junta')
# (3967, 'Las Cruces')
# (3968, 'Breckenridge')
# (3969, 'Temple')
# (3970, 'Ozona')
# (3980, 'Vail')
# (3982, 'Richmond Heights')
# (3983, 'Mansfield')
# (3984, 'Columbus')
# (3985, 'Lawton')
# (3986, 'Fort Collins')
# (3987, 'Flagstaff')
# (3988, 'South Lake Tahoe')
# (3989, 'Twin Falls')
# (3990, 'Vineyard Haven MA')
# (3991, 'Concord NH')
# (3992, 'Groton CT')
# (3993, 'Saint Cloud')
# (3995, 'Columbus Mississippi')
# (3997, 'Hoquiam')
# (3998, 'Erie')
# (3999, 'Barnstable')
# (4000, 'Sedona')
# (4001, 'Morgantown')
# (4002, 'Charleston')
# (4003, 'Scranton')
# (4004, 'Bemidji')
# (4008, 'Fargo')
# (4009, 'Kansas City')
# (4011, 'Gillette')
# (4030, 'State College Pennsylvania')
# (4042, 'Meridian')
# (4043, 'Springfield')
# (4044, 'Cortez')
# (4045, 'Hayden')
# (4046, 'Gallup')
# (4047, 'Liberal')
# (4048, 'Lamar')
# (4049, 'Goodland')
# (4050, 'Cody')
# (4053, 'Springfield')
# (4059, 'Joplin')
# (4060, 'Allentown')
# (4061, 'Bentonville')
# (4064, 'South Bend')
# (4085, 'Fort Wayne IN')
# (4086, 'Arcata CA')
# (4087, 'Jacksonville NC')
# (4088, 'Tuscaloosa AL')
# (4089, 'Dubuque IA')
# (4380, 'Aberdeen')
# (4381, 'Albany')
# (4382, 'Athens')
# (4383, 'Alamogordo')
# (4384, 'Waterloo')
# (4385, 'Walla Walla')
# (4386, 'Alpena')
# (4387, 'Watertown')
# (4388, 'Bradford')
# (4389, 'Scottsbluff')
# (4390, 'Beckley')
# (4391, 'Brunswick')
# (4392, 'Burlington')
# (4393, 'Crescent City')
# (4394, 'Cape Girardeau')
# (4395, 'Sault Ste Marie')
# (4396, 'Clarksburg')
# (4397, 'Port Angeles')
# (4398, 'Hancock')
# (4399, 'Dodge City')
# (4400, 'Du Bois')
# (4401, 'Eau Claire')
# (4402, 'Elko')
# (4403, 'New Bedford')
# (4404, 'Fayetteville')
# (4405, 'Glasgow')
# (4406, 'Grand Island')
# (4407, 'Hot Springs')
# (4408, 'Huntington')
# (4410, 'Kirksville')
# (4411, 'Jamestown')
# (4412, 'Laramie')
# (4413, 'Latrobe')
# (4414, 'North Platte')
# (4415, 'Lebanon')
# (4416, 'Klamath Falls')
# (4417, 'Lancaster')
# (4418, 'Lewistown')
# (4419, 'Lynchburg')
# (4420, 'Muskegon')
# (4421, 'Miles City')
# (4422, 'Muscle Shoals')
# (4423, 'North Bend')
# (4424, 'Owensboro')
# (4425, 'Hattiesburg/Laurel')
# (4426, 'Pocatello')
# (4427, 'Pierre')
# (4428, 'Pellston')
# (4429, 'Portsmouth')
# (4430, 'Reading')
# (4431, 'Rhinelander')
# (4432, 'Rock Springs')
# (4433, 'Rutland')
# (4434, 'San Luis Obispo')
# (4435, 'Sheridan')
# (4436, 'Saranac Lake')
# (4437, 'Salina')
# (4438, 'Santa Maria')
# (4439, 'Tupelo')
# (4440, 'Quincy')
# (4441, 'Victoria')
# (4442, 'Valdosta')
# (4443, 'Worland')
# (4444, 'Yakima')
# (4595, 'Adak Island')
# (4596, 'Gustavus')
# (4597, 'Skagway')
# (4598, 'Holy Cross')
# (4599, 'Haines')
# (4600, 'Kalskag')
# (4601, 'Mcgrath')
# (4602, 'Mountain Village')
# (4603, 'Aniak')
# (4604, 'Chevak')
# (4605, 'Wrangell')
# (4606, 'Molokai')
# (4737, 'Aleknagik')
# (4738, 'Bluefield')
# (4739, 'Greenville')
# (4740, 'Pasco')
# (4741, 'Akutan')
# (4742, 'Lopez')
# (5019, 'Waikoloa Village')
# (5027, 'Worcester')
# (5034, 'Bremerton')
# (5035, 'Spencer')
# (5036, 'Jefferson City')
# (5040, 'Provincetown')
# (5050, 'Fullerton')
# (5051, 'Concord')
# (5058, 'Hailey')
# (5061, 'Mason City')
# (5062, 'Mesa')
# (5068, 'Anaktuvuk Pass')
# (5069, 'Anvik')
# (5070, 'Atqasuk')
# (5071, 'Gambell')
# (5072, 'Hooper Bay')
# (5073, 'Kaltag')
# (5074, "St Mary's")
# (5075, 'Kivalina')
# (5076, 'Mekoryuk')
# (5077, 'Ruby')
# (5078, 'Shishmaref')
# (5079, 'Savoonga')
# (5080, 'Noatak')
# (5084, 'Arctic Village')
# (5093, 'Hagerstown')
# (5096, 'Sand Point')
# (5108, 'Deering')
# (5116, 'Igiugig')
# (5117, 'New Stuyahok')
# (5118, 'King Cove')
# (5119, 'Port Heiden')
# (5120, 'Togiak Village')
# (5151, 'Escanaba')
# (5152, 'Yakutat')
# (5163, 'Marion')
# (5170, 'Iron Mountain')
# (5171, 'Marquette')
# (5172, 'Allakaket')
# (5176, 'Michigan City')
# (5177, 'Seward')
# (5178, 'Grand Marais')
# (5179, 'Wausau')
# (5188, 'Muncie')
# (5189, 'Lafayette')
# (5190, 'Georgetown')
# (5191, 'Las Vegas')
# (5192, 'Kenosha')
# (5193, 'Montrose CO')
# (5194, 'Riverton WY')
# (5195, 'Pendleton')
# (5207, 'Oshkosh')
# (5212, 'Wenatchee')
# (5234, 'Dallas')
# (5240, 'Gary')
# (5241, 'Brainerd')
# (5242, 'Lewisburg')
# (5243, 'Greenville')
# (5244, 'Chefornak')
# (5245, 'Oxnard')
# (5248, 'Scotia NY')
# (5256, 'St. Augustine Airport')
# (5259, 'Santa Rosa')
# (5260, 'Kissimmee')
# (5261, 'Lake City')
# (5262, 'DeLand')
# (5263, 'Green Cove Springs')
# (5265, 'Logan')
# (5266, 'Brigham City')
# (5267, 'Malad City')
# (5268, 'Aspen')
# (5270, 'Kerrville')
# (5272, 'Georgetown')
# (5274, 'Great Bend')
# (5275, 'Hays')
# (5276, 'Null')
# (5277, 'Ely')
# (5278, 'Grand Rapids MN')
# (5279, 'Thief River Falls')
# (5280, 'Eagle River')
# (5281, 'Minocqua - Woodruff')
# (5282, 'Ankeny')
# (5284, 'Corpus Christi')
# (5285, 'Catalina Island')
# (5286, 'Mojave')
# (5290, 'Hutchinson')
# (5293, 'Rosecrans')
# (5296, 'Camp Douglas')
# (5297, 'Gunnison')
# (5299, 'Torrance')
# (5300, 'Manistee')
# (5301, 'Punta Gorda')
# (5302, 'Frenchville')
# (5303, 'Jamestown')
# (5305, 'Somerset')
# (5306, 'Weyers Cave')
# (5307, 'Devils Lake')
# (5308, 'Dickinson')
# (5309, 'Sidney')
# (5310, 'Chadron')
# (5311, 'Alliance')
# (5312, 'McCook')
# (5313, 'Marathon')
# (5314, 'Glendive')
# (5315, 'Wolf Point')
# (5316, 'West Yellowstone')
# (5317, 'Alamosa')
# (5318, 'Moab')
# (5319, 'Ely')
# (5320, 'Vernal')
# (5321, 'Ruidoso')
# (5322, 'Show Low')
# (5323, 'McCall')
# (5324, 'Salmon')
# (5325, 'Mammoth Lakes')
# (5326, 'Friday Harbor')
# (5327, 'Eastsound')
# (5328, 'Astoria')
# (5329, 'Newport')
# (5330, 'Emmonak')
# (5331, 'Unalakleet')
# (5332, 'Kuparuk')
# (5333, 'Shageluk')
# (5334, 'Nuiqsut')
# (5335, 'Eek')
# (5336, 'Kasigluk')
# (5337, 'Kwethluk')
# (5338, 'Kwigillingok')
# (5339, 'Marshall')
# (5340, 'Russian Mission')
# (5341, 'Koliganek')
# (5342, 'Manokotak')
# (5343, 'Chalkyitsik')
# (5344, 'Eagle')
# (5345, 'Hughes')
# (5346, 'Huslia')
# (5347, 'Nulato')
# (5348, 'Venetie')
# (5349, 'Beaver')
# (5350, 'Central')
# (5351, 'Shungnak')
# (5352, 'Inyokern')
# (5353, 'Visalia')
# (5354, 'Merced')
# (5357, 'Goodyear')
# (5363, 'Angoon')
# (5364, 'Elfin Cove')
# (5365, 'Funter Bay')
# (5366, 'Hoonah')
# (5367, 'Kake')
# (5368, 'Metakatla')
# (5369, 'Hydaburg')
# (5370, 'Egegik')
# (5371, 'Perryville')
# (5372, 'Pilot Point')
# (5373, 'South Naknek')
# (5374, 'Akhiok')
# (5375, 'Karluk')
# (5376, 'Larsen Bay')
# (5377, 'Ambler')
# (5378, 'Buckland')
# (5379, 'Kiana')
# (5380, 'Kobuk')
# (5381, 'Noorvik')
# (5382, 'Selawik')
# (5383, 'Brevig Mission')
# (5384, 'Elim')
# (5385, 'Golovin')
# (5386, 'Teller')
# (5387, 'Wales')
# (5388, 'White Mountain')
# (5389, 'Koyuk')
# (5390, 'St. Michael')
# (5391, 'Shaktoolik')
# (5392, 'Tin City')
# (5393, 'Atka')
# (5394, 'Yakataga')
# (5395, 'Alakanuk')
# (5396, 'Kipnuk')
# (5397, 'False Pass')
# (5398, 'Nelson Lagoon')
# (5399, 'Cold Bay')
# (5400, 'Klawock')
# (5401, 'Quinhagak')
# (5402, 'Kotlik')
# (5403, 'Koyukuk')
# (5404, 'Scammon Bay')
# (5405, 'Nondalton')
# (5406, 'Kongiganak')
# (5407, 'Nikolai')
# (5408, 'Akiak')
# (5409, 'Wainwright')
# (5415, 'Chenega')
# (5416, 'Tok')
# (5417, 'Circle')
# (5418, 'Sleetmute')
# (5419, 'Healy')
# (5420, 'Klawock')
# (5421, 'Lake Minchumina')
# (5422, 'Manley Hot Springs')
# (5525, 'Martinsburg')
# (5578, 'Rock Hill')
# (5579, 'Pittsburgh')
# (5580, 'Jacksonville')
# (5581, 'Atlanta')
# (5591, 'Columbus')
# (5592, 'Addison')
# (5593, 'Destin')
# (5599, 'Kinston')
# (5600, 'Kill Devil Hills')
# (5633, 'Provo')
# (5634, 'Steamboat Springs')
# (5635, 'Delta')
# (5636, 'Richfield')
# (5637, 'Price')
# (5638, 'Los Alamos')
# (5639, 'Lake Havasu City')
# (5640, 'Winslow')
# (5641, 'Douglas')
# (5662, 'Bartow')
# (5665, 'Livermore')
# (5666, 'Mariposa')
# (5670, 'Palm Springs')
# (5671, 'Santa Monica')
# (5672, 'Palm Springs')
# (5673, 'Scottsdale')
# (5674, 'Olympia')
# (5675, 'Davis-Woodland-Winters')
# (5676, 'Rifle')
# (5677, 'SARATOGA')
# (5678, 'Atlanta')
# (5679, 'Bloomington')
# (5680, 'Stuart')
# (5681, 'Morristown')
# (5682, 'Napa')
# (5683, 'San Diego')
# (5685, 'Venice')
# (5686, 'Pahokee')
# (5687, 'Panama City')
# (5688, 'San Bernardino')
# (5693, 'San Carlos')
# (5697, 'Rocky Mount')
# (5698, 'Whittier')
# (5699, 'Soldotna')
# (5700, 'El Cajon')
# (5701, 'San Clemente Island')
# (5704, 'Truckee')
# (5709, 'Atlanta')
# (5711, 'Dell')
# (5712, 'Livingston-Montana')
# (5713, 'Big Timber')
# (5714, 'Holland')
# (5720, 'Monument Valley')
# (5724, 'Lakeland')
# (5727, 'New York')
# (5729, 'Murrieta-Temecula')
# (5733, 'Port Clinton')
# (5734, 'Dayton')
# (5735, 'Richmond')
# (5736, 'Findley')
# (5745, 'Spearfish-South Dakota')
# (5753, 'Olive Branch')
# (5757, 'Broomfield-CO')
# (5758, 'Salem')
# (5759, 'Tunica')
# (5768, 'Milwaukee')
# (5769, 'Janesville')
# (5771, 'Arlington')
# (5772, 'Lawrenceville')
# (5773, 'Bowling Green')
# (5774, 'Tulsa')
# (5779, 'Bryce Canyon')
# (5780, 'Burlington')
# (5786, 'Olathe')
# (5787, 'Easton')
# (5790, 'Yuba City')
# (5792, 'Duncan')
# (5793, 'Uvalde')
# (5794, 'Lockport')
# (5795, 'Concord')
# (5796, 'Ocean Reef Club Airport')
# (5805, 'Athens')
# (5806, 'Springfield')
# (5814, 'Topeka')
# (5815, 'Uvalde')
# (5816, 'Null')
# (5817, 'Smyrna')
# (5818, 'Sewanee')
# (5821, 'DALLAS')
# (5822, 'Chicago-Wheeling')
# (5823, 'Kelso')
# (5832, 'Wilmington')
# (5833, 'Tucson')
# (5834, 'Casa Grande')
# (5835, 'Mobile')
# (5836, 'Buckeye')
# (5837, 'Gila Bend')
# (5838, 'Athens')
# (5839, 'Sterling')
# (5840, 'Rawlins')
# (5842, 'Caldwell')
# (5843, 'Kaiser Lake Ozark')
# (5844, 'Thomasville')
# (5845, 'Henderson')
# (5847, 'Tifton')
# (5851, 'Phoenix ')
# (5855, 'Farmingdale')
# (5859, 'Hondo')
# (5861, 'McKinley Park')
# (5862, 'Anchorage')
# (5863, 'Prospect Creek')
# (5867, 'Wheeling')
# (5868, 'Fitzgerald')
# (5873, 'Rockport')
# (5910, 'Cordele')
# (5911, 'Ormond Beach')
# (5914, 'Troutdale')
# (5915, 'Hillsboro')
# (5916, 'New York')
# (5921, 'Bend')
# (5922, 'Christmas Valley')
# (5923, 'Burns')
# (5924, 'Prineville')
# (5925, 'Red Bluff')
# (5926, 'Novato')
# (5927, 'Lakeview')
# (5928, 'Tillamook')
# (5929, 'Ontario')
# (5930, 'The Dalles')
# (5931, 'Gaithersburg')
# (5937, 'Charelvoix')
# (5943, 'Flagler')
# (5944, 'Morrisville')
# (5945, 'Dallas')
# (5947, 'Washington County')
# (5948, 'Block Island')
# (5949, 'Nightmute')
# (5950, 'Toksook Bay')
# (5953, 'Bainbridge')
# (5957, 'Silver Springs')
# (5958, 'Los Angeles')
# (5959, 'Madera')
# (5985, 'Apalachicola')
# (5996, 'Douglas')
# (5997, 'Fort Pierce')
# (5998, 'Taunton')
# (5999, 'Plymouth')
# (6000, 'North Kingstown')
# (6001, 'Norwood')
# (6002, 'Westfield')
# (6003, 'Willimantic')
# (6004, 'Montgomery')
# (6005, 'Harrisburg')
# (6006, 'Marshfield')
# (6007, 'Danbury')
# (6008, 'Nashua')
# (6009, 'Lawrence')
# (6010, 'Oxford')
# (6011, 'Fitchburg')
# (6012, 'Villa Rica')
# (6013, 'Cartersville')
# (6014, 'Centre')
# (6015, 'Rome')
# (6016, 'Gadsden')
# (6017, 'Knoxville')
# (6018, 'Winder')
# (6019, 'Sylvania')
# (6020, 'Dalton')
# (6021, 'Carrollton')
# (6022, 'LaGrange')
# (6023, 'Milledgeville')
# (6024, 'Pine Mountain')
# (6025, 'Atlanta')
# (6026, 'Gainesville')
# (6027, 'New Philadelpha')
# (6028, 'Darlington')
# (6029, 'Hilton Head Island')
# (6030, 'Augusta')
# (6031, 'Morganton')
# (6032, 'Pikeville')
# (6033, 'Locust Grove')
# (6034, 'Toccoa')
# (6046, 'Fort Worth')
# (6047, 'East Troy')
# (6068, 'Lawrence')
# (6069, 'Wellington')
# (6070, 'Pompano Beach')
# (6072, 'Alabaster')
# (6074, 'Carefree')
# (6081, 'Indianapolis')
# (6082, 'London')
# (6083, 'Fredericksburg')
# (6091, 'Racine')
# (6096, 'Redlands')
# (6097, 'Riverside')
# (6098, 'Tacoma')
# (6100, 'Gulf Shores')
# (6107, 'Hazleton')
# (6108, 'Cumberland')
# (6109, 'Key West')
# (6113, 'Lone Rock')
# (6114, 'Phillips')
# (6115, 'Monroe')
# (6116, 'Joliet')
# (6117, 'Peru')
# (6118, 'Jackson')
# (6121, 'Connellsville')
# (6122, 'Bedford')
# (6123, 'Philadelphia')
# (6124, 'Okeechobee')
# (6125, 'Sebring')
# (6126, 'Avon Park')
# (6127, 'Winter Haven')
# (6128, 'Zephyrhills')
# (6129, 'Ocala')
# (6130, 'Jesup')
# (6131, 'Madison')
# (6132, 'Newnan')
# (6133, 'Thomson')
# (6134, 'Aiken')
# (6135, 'Camden')
# (6136, 'Lumberton')
# (6137, 'Pinehurst-Southern Pines')
# (6138, 'Rockingham')
# (6139, 'Baraboo')
# (6140, 'Statesville')
# (6141, 'Burlington')
# (6142, 'Lock Haven')
# (6143, 'Zelienople')
# (6144, 'Lorain-Elyria')
# (6145, 'Cleveland')
# (6146, 'Dunkirk')
# (6147, 'Mount Holly')
# (6148, 'Linden')
# (6149, 'Angola')
# (6150, 'Warsaw')
# (6151, 'Van Wert')
# (6152, 'Marshall')
# (6153, 'Batavia')
# (6154, 'Clearwater')
# (6156, 'Chicago')
# (6157, 'Jasper')
# (6159, 'North Myrtle Beach')
# (6160, 'Lansing')
# (6161, 'Ramona')
# (6177, 'Coldwater')
# (6178, 'Wilkes-Barre')
# (6179, 'Willoughby')
# (6183, 'Frankfort')
# (6184, 'Lewiston')
# (6187, 'Tomah')
# (6188, 'Marco Island Airport')
# (6189, 'Drummond Island')
# (6190, 'Gladwin')
# (6191, 'South Haven')
# (6192, 'Marshfield')
# (6193, 'Wisconsin Rapids')
# (6194, 'Clinton')
# (6195, 'Beverly')
# (6199, 'Poplar Bluff')
# (6200, 'Somerville')
# (6201, 'Eastport')
# (6202, 'Keokuk')
# (6206, 'St. Paul')
# (6214, 'Oconomowoc')
# (6223, 'Hamilton')
# (6239, 'Fond du Lac')
# (6240, 'Waupaca')
# (6241, 'Stevens Point')
# (6244, 'Newberry')
# (6248, 'Galion')
# (6251, 'Clarksville')
# (6252, 'Lompoc')
# (6253, 'Coatesville')
# (6258, 'Lake Placid')
# (6261, 'Lima')
# (6263, 'Brunswick')
# (6264, 'Beaver Falls')
# (6265, 'Georgetown')
# (6266, 'Cleveland')
# (6267, 'Renton')
# (6268, 'La Verne')
# (6269, 'Cross City')
# (6270, 'Clemson')
# (6271, 'Wichita')
# (6273, 'Calhoun')
# (6274, 'Cornelia')
# (6275, 'Georgetown')
# (6276, 'Rhinebeck')
# (6278, 'Sidney')
# (6283, 'Kapolei')
# (6286, 'East Tawas')
# (6287, 'Huntsville')
# (6288, 'Leesburg')
# (6289, 'Anoka')
# (6296, 'Williamson')
# (6298, 'Boulder')
# (6304, 'Palo Alto')
# (6308, 'Mesa')
# (6309, 'Cooldige')
# (6310, 'Cottonwood')
# (6313, 'Phoenix')
# (6314, 'Wickenburg')
# (6316, 'Pontiac')
# (6318, 'Keene')
# (6321, 'Glasgow')
# (6325, 'Iowa City')
# (6328, 'Windom')
# (6329, 'Longview')
# (6331, 'Annapolis')
# (6337, 'Pecos')
# (6338, 'Hattiesburg')
# (6342, 'Yankton')
# (6355, 'Hayward')
# (6358, 'Ann Arbor')
# (6377, 'Hampton')
# (6386, 'Salt Lake City')
# (6390, 'Immokalee ')
# (6392, 'Cambria')
# (6394, 'Petersburg')
# (6398, 'Sheboygan')
# (6405, 'Marana')
# (6406, 'Glendale')
# (6407, 'Safford')
# (6415, 'Sikeston')
# (6417, 'Queensbury')
# (6418, 'Ballston Spa')
# (6419, 'Crystal River')
# (6420, 'Baltimore')
# (6421, 'Lincoln')
# (6422, 'Fostoria')
# (6423, 'Fryeburg')
# (6424, 'Placida')
# (6425, 'New Orleans')
# (6426, "Coeur d'Alene")
# (6427, 'Beaumont')
# (6428, 'Danville')
# (6430, 'Titusville')
# (6435, 'Houston')
# (6436, 'Eden Prairie')
# (6438, 'Olathe')
# (6453, 'West Goshen Township')
# (6454, 'Manassas')
# (6455, 'Angleton')
# (6462, 'Shelbyville')
# (6466, 'Enumclaw')
# (6478, 'Winnsboro')
# (6484, 'Rochester')
# (6486, 'Newton')
# (6489, 'Columbus')
# (6490, 'Fort Bridger')
# (6491, 'Prosser')
# (6492, 'Chehalis')
# (6493, 'Mattawa')
# (6494, 'Evanston')
# (6495, 'Sabetha')
# (6496, 'Mount Pleasant')
# (6497, 'Americus')
# (6498, 'Eufala')
# (6499, 'Saluda')
# (6500, 'Manteo')
# (6501, 'Auburn')
# (6502, 'Endicott')
# (6503, 'Bessemer')
# (6504, 'Ellicott')
# (6505, 'Crystal')
# (6506, 'Quitman')
# (6507, 'Dublin')
# (6512, 'Corvallis')
# (6514, 'Scranton')
# (6515, 'Morristown')
# (6519, 'Chatsworth')
# (6521, 'Ogden')
# (6523, 'Poteau')
# (6524, 'Akron')
# (6525, 'Shelton')
# (6526, 'Napakiak')
# (6527, 'Napaskiak')
# (6528, 'Tok')
# (6531, 'Liberty')
# (6535, 'Doylestown')
# (6539, 'Washington')
# (6540, 'Engelhard')
# (6542, 'Stillwater')
# (6543, 'Okmulgee')
# (6544, 'Cushing')
# (6545, 'Clinton')
# (6546, 'Winfield')
# (6547, 'Oklahoma City')
# (6548, 'Shreveport')
# (6549, 'Stephenville')
# (6550, 'Perry')
# (6551, 'Hamilton')
# (6552, 'Ada')
# (6553, 'Misquite')
# (6554, 'Denton')
# (6555, 'Austin')
# (6556, 'Lago Vista')
# (6557, 'Brenham')
# (6558, 'Lakeway')
# (6559, 'Iraan')
# (6560, 'San Antonio')
# (6562, 'North Wilkesboro')
# (6563, 'Charleston')
# (6564, 'Danville')
# (6565, 'Brookneal')
# (6567, 'Cheraw')
# (6568, 'Wuchula')
# (6583, 'Conway')
# (6617, 'Asheboro')
# (6619, 'Wallace')
# (6620, 'Emporia')
# (6621, 'El Monte')
# (6624, 'Pineville')
# (6629, 'Stinson')
# (6630, 'Sallisaw')
# (6631, 'Jasper')
# (6632, 'El dorado springs')
# (6633, 'Marfa')
# (6634, 'Alpine')
# (6638, 'Upland')
# (6639, 'Mount Sterling')
# (6640, 'Elkhart')
# (6641, 'Nappanee ')
# (6642, 'Columbia')
# (6643, 'Grove')
# (6644, 'Mc Pherson')
# (6645, 'Greenville')
# (6646, 'Perry')
# (6647, 'Hartsville')
# (6648, 'Chapel Hill')
# (6651, 'Oak Island')
# (6652, 'Richmond')
# (6656, 'Oxford')
# (6657, 'Leesburg')
# (6667, 'Chino')
# (6672, 'London')
# (6677, 'Paso Robles')
# (6680, 'Half Moon Bay')
# (6683, 'Lancaster')
# (6706, 'Roxboro')
# (6715, 'Talladega')
# (6716, 'Greenville')
# (6717, 'Mankato')
# (6719, 'Troy')
# (6720, 'Sylacauga')
# (6721, 'Enterprise')
# (6722, 'Tucson')
# (6723, 'Alexander City')
# (6727, 'Meriden')
# (6734, 'Ridgely')
# (6735, 'New Castle')
# (6736, 'Scott City')
# (6737, 'Holdredge')
# (6738, 'Pratt')
# (6740, 'Wahoo')
# (6741, 'Lexington')
# (6742, 'Sublette')
# (6743, 'Council Bluffs')
# (6744, 'Kokomo')
# (6745, 'Neodesha')
# (6746, 'Sutton')
# (6747, 'Elkhart')
# (6748, 'Denver')
# (6749, 'Galesburg')
# (6750, 'Guymon')
# (6751, 'Meade')
# (6752, 'Shell Knob')
# (6753, 'Ulysses')
# (6754, 'Flagler')
# (6755, 'Independence')
# (6756, 'Augusta')
# (6757, 'Larned')
# (6758, 'Lampasas')
# (6759, 'Bay City')
# (6760, 'Paris')
# (6761, 'Coffeyville')
# (6762, 'Summit')
# (6763, 'Greeley')
# (6764, 'Memphis')
# (6765, 'Oakley')
# (6766, 'Fremont')
# (6767, 'La Grande')
# (6769, 'Mount Pocono')
# (6770, 'Quakertown')
# (6772, 'Banning')
# (6775, 'Norfolk  Nebraska')
# (6778, 'Arlington')
# (6784, 'Tampa')
# (6814, 'Montauk')
# (6815, 'Valparaiso IN')
# (6831, 'Ludington')
# (6832, 'San Jose')
# (6848, 'Camarillo - CA')
# (6854, 'Watsonville')
# (6856, 'Williamsburg')
# (6873, 'Marysville')
# (6944, 'Alton/St Louis')
# (6945, 'Alexandria')
# (6946, 'Columbus')
# (6947, 'Brady')
# (6948, 'Bishop')
# (6949, 'Baker City')
# (6950, 'Big Piney')
# (6951, 'Mountain Home')
# (6952, 'Battle Creek')
# (6953, 'Burley')
# (6954, 'Charles City')
# (6955, 'Chanute')
# (6956, 'Jacksonville')
# (6957, 'Crossville')
# (6958, 'Fort Belvoir')
# (6959, 'Daggett')
# (6960, 'Deming')
# (6961, 'Mercury')
# (6962, 'Needles')
# (6963, 'Crestview')
# (6964, 'Eureka')
# (6965, 'San Marcos')
# (6966, 'Hayward')
# (6967, 'Junction')
# (6968, 'Monticello')
# (6969, 'Lovelock')
# (6970, 'Mobridge')
# (6971, 'Mc Comb')
# (6972, 'Carbondale/Murphysboro')
# (6973, 'Eastover')
# (6974, 'Brunswick')
# (6975, 'Mayport')
# (6976, 'Orangeburg')
# (6977, 'Columbus')
# (6978, 'Ottumwa')
# (6979, 'Fort Rucker/Ozark')
# (6980, 'Pinedale')
# (6981, 'Poughkeepsie')
# (6982, 'New Richmond')
# (6983, 'Russell')
# (6984, 'Redwood Falls')
# (6985, 'Salinas')
# (6986, 'Sonora')
# (6987, 'Benton')
# (6988, 'Tonopah')
# (6989, 'Aurora')
# (6990, 'Ukiah')
# (6991, 'Oxford')
# (6992, 'Huntsville')
# (6993, 'Valentine')
# (6994, 'Winnemucca')
# (6995, 'Woodward')
# (6996, 'Cocoa Beach')
# (6997, 'Groom Lake')
# (6998, 'Zanesville')
# (7048, 'Nenana')
# (7049, 'Wasilla')
